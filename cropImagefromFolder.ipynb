# %%
import os
import numpy as np
import cv2
import glob
import matplotlib.pyplot as plt
from PIL import Image
from skimage import data, io, filters
from scipy import ndimage
from sklearn import manifold, datasets

# %%
# GANTI PATH
path = 'D:/DATA/Institut Teknologi Sepuluh Nopember/MATERI/Belajar Python/Jupyter/CobaUNet/train/image/*.jpg'
images = [cv2.imread(file) for file in glob.glob(path)]

# %%
# GANTI DIREC
n = 100
direc = 'D:/DATA/Institut Teknologi Sepuluh Nopember/MATERI/Belajar Python/Jupyter/CobaUNet/train/image256/'
for i in range (1,n+1):
    #Subsection of the image
    images[i-1]=images[i-1][0:256,61:317]
    print('Creating...'+str(i)+'.tif')
    path=str(i)+'.tif'
    io.imsave(direc+path,images[i-1])
# Out:
# Creating...1.tif
# Creating...2.tif
# Creating...3.tif
# Creating...4.tif
# Creating...5.tif
# Creating...6.tif
# Creating...7.tif
# Creating...8.tif
# Creating...9.tif
# Creating...10.tif
# Creating...11.tif
# Creating...12.tif
# Creating...13.tif
# Creating...14.tif
# Creating...15.tif
# Creating...16.tif
# Creating...17.tif
# Creating...18.tif
# Creating...19.tif
# Creating...20.tif
# Creating...21.tif
# Creating...22.tif
# Creating...23.tif
# Creating...24.tif
# Creating...25.tif
# Creating...26.tif
# Creating...27.tif
# Creating...28.tif
# Creating...29.tif
# Creating...30.tif
# Creating...31.tif
# Creating...32.tif
# Creating...33.tif
# Creating...34.tif
# Creating...35.tif
# Creating...36.tif
# Creating...37.tif
# Creating...38.tif
# Creating...39.tif
# Creating...40.tif
# Creating...41.tif
# Creating...42.tif
# Creating...43.tif
# Creating...44.tif
# Creating...45.tif
# Creating...46.tif
# Creating...47.tif
# Creating...48.tif
# Creating...49.tif
# Creating...50.tif
# ...
